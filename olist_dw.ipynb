# %%
import pandas as pd
import numpy as np
import os
import warnings
warnings.filterwarnings('ignore')

# %%
#loading flat files
df_customers= pd.read_csv("/Users/sansitkabi/Desktop/cs689 final dataset/olist_customers_dataset.csv")
df_geo_location = pd.read_csv("/Users/sansitkabi/Desktop/cs689 final dataset/olist_geolocation_dataset.csv")
df_order_items = pd.read_csv("/Users/sansitkabi/Desktop/cs689 final dataset/olist_order_items_dataset.csv")
df_order_payments = pd.read_csv("/Users/sansitkabi/Desktop/cs689 final dataset/olist_order_payments_dataset.csv")
df_order_reviews = pd.read_csv("/Users/sansitkabi/Desktop/cs689 final dataset/olist_order_reviews_dataset.csv")
df_orders = pd.read_csv("/Users/sansitkabi/Desktop/cs689 final dataset/olist_orders_dataset.csv")
df_products = pd.read_csv("/Users/sansitkabi/Desktop/cs689 final dataset/olist_products_dataset.csv")
df_sellers = pd.read_csv("/Users/sansitkabi/Desktop/cs689 final dataset/olist_sellers_dataset.csv")
df_prod_category = pd.read_csv("/Users/sansitkabi/Desktop/cs689 final dataset/product_category_name_translation.csv")

#2nd source olist_marketing_qualified_leads_dataset
df_closed_deals = pd.read_csv("/Users/sansitkabi/Desktop/cs689 final dataset/olist_closed_deals_dataset.csv")
df_mql = pd.read_csv("/Users/sansitkabi/Desktop/cs689 final dataset/olist_marketing_qualified_leads_dataset.csv")

# %%
##shape of dfs
print("Structure of customers:",df_customers.shape)
print('\n')
print("Structure of geo_location:",df_geo_location.shape)
print('\n')
print("Structure of order_items:",df_order_items.shape)
print('\n')
print("Structure of order_payments:",df_order_payments.shape)
print('\n')
print("Structure of order_reviews:",df_order_reviews.shape)
print('\n')
print("Structure of orders:",df_orders.shape)
print('\n')
print("Structure of products:",df_products.shape)
print('\n')
print("Structure of sellers:",df_sellers.shape)
print('\n')
print("Structure of prod_category:",df_prod_category.shape)
print('\n')
print("Structure of closed_deals:",df_closed_deals.shape)
print('\n')
print("Structure of mql:",df_mql.shape)
# Out:
# Structure of customers: (99441, 5)
#
#
# Structure of geo_location: (1000163, 5)
#
#
# Structure of order_items: (112650, 7)
#
#
# Structure of order_payments: (103886, 5)
#
#
# Structure of order_reviews: (99224, 7)
#
#
# Structure of orders: (99441, 8)
#
#
# Structure of products: (32951, 9)
#
#
# Structure of sellers: (3095, 4)
#
#
# Structure of prod_category: (71, 2)
#
#
# Structure of closed_deals: (842, 14)
#
#
# Structure of mql: (8000, 4)

# %%
## print the columns of all dataframes

print('The columns of olist_customers are :- ',list(df_customers.columns))
print('\n')
print('The columns of olist_sellers are :-  ',list(df_sellers.columns))
print('\n')
print('The columns of olist_order_reviews are :-  ',list(df_order_reviews.columns))
print('\n')
print('The columns of olist_order_items are :-  ',list(df_order_items.columns))
print('\n')
print('The columns of olist_products are :-  ',list(df_products.columns))
print('\n')
print('The columns of olist_geolocation are :-  ',list(df_geo_location.columns))
print('\n')
print('The columns of product_category_name_translation are :-  ',list(df_prod_category.columns))
print('\n')
print('The columns of olist_orders_dataset are :-  ',list(df_orders.columns))
print('\n')
print('The columns of olist_order_payments are :-  ',list(df_order_payments.columns))
print('\n')
print('The columns of closed deals are :-  ',list(df_closed_deals.columns))
print('\n')
print('The columns of marketing qualified leads are :-  ',list(df_mql.columns))
# Out:
# The columns of olist_customers are :-  ['customer_id', 'customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state']
#
#
# The columns of olist_sellers are :-   ['seller_id', 'seller_zip_code_prefix', 'seller_city', 'seller_state']
#
#
# The columns of olist_order_reviews are :-   ['review_id', 'order_id', 'review_score', 'review_comment_title', 'review_comment_message', 'review_creation_date', 'review_answer_timestamp']
#
#
# The columns of olist_order_items are :-   ['order_id', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'price', 'freight_value']
#
#
# The columns of olist_products are :-   ['product_id', 'product_category_name', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm']
#
#
# ...

# %%
#data types
print(df_customers.dtypes)
print('\n')
print(df_sellers.dtypes)
print('\n')
print(df_order_reviews.dtypes)
print('\n')
print(df_order_items.dtypes)
print('\n')
print(df_products.dtypes)
print('\n')
print(df_geo_location.dtypes)
print('\n')
print(df_prod_category.dtypes)
print('\n')
print(df_orders.dtypes)
print('\n')
print(df_order_payments.dtypes)
print('\n')
print(df_closed_deals.dtypes)
print('\n')
print(df_mql.dtypes)
print('\n')
# Out:
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix     int64
# customer_city               object
# customer_state              object
# dtype: object
#
#
# seller_id                 object
# seller_zip_code_prefix     int64
# seller_city               object
# seller_state              object
# dtype: object
#
#
# review_id                  object
# order_id                   object
# review_score                int64
# review_comment_title       object
# review_comment_message     object
# review_creation_date       object
# review_answer_timestamp    object
# dtype: object
#
#
# order_id                object
# order_item_id            int64
# product_id              object
# seller_id               object
# shipping_limit_date     object
# price                  float64
# freight_value          float64
# dtype: object
#
#
# product_id                     object
# product_category_name          object
# ...

# %%
df_closed_deals.head()
# Out:
#                              mql_id                         seller_id  \
# 0  5420aad7fec3549a85876ba1c529bd84  2c43fb513632d29b3b58df74816f1b06
# 1  a555fb36b9368110ede0f043dfc3b9a0  bbb7d7893a450660432ea6652310ebb7
# 2  327174d3648a2d047e8940d7d15204ca  612170e34b97004b3ba37eae81836b4c
# 3  f5fee8f7da74f4887f5bcae2bafb6dd6  21e1781e36faf92725dde4730a88ca0f
# 4  ffe640179b554e295c167a2f6be528e0  ed8cb7b190ceb6067227478e48cf8dde
#
#                              sdr_id                             sr_id  \
# 0  a8387c01a09e99ce014107505b92388c  4ef15afb4b2723d8f3d81e51ec7afefe
# 1  09285259593c61296eef10c734121d5b  d3d1e91a157ea7f90548eef82f1955e3
# 2  b90f87164b5f8c2cfa5c8572834dbe3f  6565aa9ce3178a5caf6171827af3a9ba
# 3  56bf83c4bb35763a51c2baab501b4c67  d3d1e91a157ea7f90548eef82f1955e3
# 4  4b339f9567d060bcea4f5136b9f5949e  d3d1e91a157ea7f90548eef82f1955e3
#
#               won_date business_segment      lead_type lead_behaviour_profile  \
# ...

# %%
df_mql.head()
# Out:
#                              mql_id first_contact_date  \
# 0  dac32acd4db4c29c230538b72f8dd87d         2018-02-01
# 1  8c18d1de7f67e60dbd64e3c07d7e9d5d         2017-10-20
# 2  b4bc852d233dfefc5131f593b538befa         2018-03-22
# 3  6be030b81c75970747525b843c1ef4f8         2018-01-22
# 4  5420aad7fec3549a85876ba1c529bd84         2018-02-21
#
#                     landing_page_id          origin
# 0  88740e65d5d6b056e0cda098e1ea6313          social
# 1  007f9098284a86ee80ddeb25d53e0af8     paid_search
# 2  a7982125ff7aa3b2054c6e44f9d28522  organic_search
# 3  d45d558f0daeecf3cccdffe3c59684aa           email
# 4  b48ec5f3b04e9068441002a19df93c6c  organic_search

# %%
df_order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
df_orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
df_order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
df_prod_category.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
#checking null values df_orders
print(df_orders.shape)
print(df_orders.isnull().sum())
#not removing any columns here as the number of na values is low
# Out:
# (99441, 8)
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
#removing columns with na values
df_closed_deals = df_closed_deals.drop(['has_company', 'has_gtin','average_stock','declared_product_catalog_size'], axis=1)
print("\n",df_closed_deals.shape)
# Out:
#  (842, 10)

# %%
#checking null values
print(df_customers.shape)
print(df_customers.isnull().sum())
# Out:
# (99441, 5)
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
#checking null values
print(df_order_items.shape)
print(df_order_items.isnull().sum())
# Out:
# (112650, 7)
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
#checking null values
print(df_order_payments.shape)
print(df_order_payments.isnull().sum())
# Out:
# (103886, 5)
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
#checking null values
print(df_sellers.shape)
print(df_sellers.isnull().sum())
# Out:
# (3095, 4)
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
#checking null values
print(df_geo_location.shape)
print(df_geo_location.isnull().sum())
# Out:
# (1000163, 5)
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
#checking null values
print(df_mql.shape)
print(df_mql.isnull().sum())
#not removing any columns here
# Out:
# (8000, 4)
# mql_id                 0
# first_contact_date     0
# landing_page_id        0
# origin                60
# dtype: int64

# %%
#checking null values
print(df_products.shape)
print(df_products.isnull().sum())
#not removing any columns here
# Out:
# (32951, 9)
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
#joining dataframes
df_orderitems_merged = df_orders.merge(df_order_items,how ='inner',on = ['order_id'],indicator='merge1')
df_orderitems_merged
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_orderitems_merged['merge1'].value_counts()
# Out:
# both          112650
# left_only          0
# right_only         0
# Name: merge1, dtype: int64

# %%
#merging customers to orderitemsmerged
df_orderitems_customers = df_orderitems_merged.merge(df_customers,how ='inner',on = ['customer_id'],indicator='merge2')
df_orderitems_customers
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_orderitems_customers_sellers_payments['payment_value'].head()
# Out:
# 0    18.12
# 1     2.00
# 2    18.59
# 3    83.69
# 4    52.77
# Name: payment_value, dtype: float64

# %%
#merging sellers to orderitemscustomers
df_orderitems_customers_sellers = df_orderitems_customers.merge(df_sellers,how ='inner',on = ['seller_id'],indicator='merge3')
df_orderitems_customers_sellers
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       8736140c61ea584cb4250074756d8f3b  ab8844663ae049fda8baf15fc928f47f
# 2       a0151737f2f0c6c0a5fd69d45f66ceea  fc2697314ab7fbeda62bb6f1afa4efcd
# 3       a3bf941183211246f0d42ad757cba127  3718e1873d5dc3e8d96c0ab783278b02
# 4       1462290799412b71be32dd880eaf4e1b  220e4b027f0294fd79d2869ef67e7db6
# ...                                  ...                               ...
# 112645  1ab38815794efa43d269d62b98dae815  a0b67404d84a70ef420a7f99ad6b190a
# 112646  b159d0ce7cd881052da94fa165617b05  e0c3bc5ce0836b975d6b2a8ce7bb0e3e
# 112647  735dce2d574afe8eb87e80a3d6229c48  d531d01affc2c55769f6b9ed410d8d3c
# 112648  25d2bfa43663a23586afd12f15b542e7  9d8c06734fde9823ace11a4b5929b5a7
# 112649  1565f22aa9452ff278638e87cc895678  56772dfbcbe7df908a284ff0d53adf7d
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
#merging payments to df_orderitems_customers_sellers
df_orderitems_customers_sellers_payments = df_orderitems_customers_sellers.merge(df_order_payments,how ='inner',on = ['order_id'],indicator='merge4')
df_orderitems_customers_sellers_payments
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       8736140c61ea584cb4250074756d8f3b  ab8844663ae049fda8baf15fc928f47f
# 4       a0151737f2f0c6c0a5fd69d45f66ceea  fc2697314ab7fbeda62bb6f1afa4efcd
# ...                                  ...                               ...
# 117596  1ab38815794efa43d269d62b98dae815  a0b67404d84a70ef420a7f99ad6b190a
# 117597  b159d0ce7cd881052da94fa165617b05  e0c3bc5ce0836b975d6b2a8ce7bb0e3e
# 117598  735dce2d574afe8eb87e80a3d6229c48  d531d01affc2c55769f6b9ed410d8d3c
# 117599  25d2bfa43663a23586afd12f15b542e7  9d8c06734fde9823ace11a4b5929b5a7
# 117600  1565f22aa9452ff278638e87cc895678  56772dfbcbe7df908a284ff0d53adf7d
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_prod_category.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
#merging products to df_prod_category
df_productscategory = df_products.merge(df_prod_category,how ='inner',on = ['product_category_name'],indicator='merge1')
df_productscategory
# Out:
#                              product_id      product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                 perfumaria
# 1      6a2fb4dd53d2cdb88e0432f1284a004c                 perfumaria
# 2      0d009643171aee696f4733340bc2fdd0                 perfumaria
# 3      b1eae565a61935e0011ee7682fef9dc9                 perfumaria
# 4      8da90b37f0fb171b4877c124f965b1f6                 perfumaria
# ...                                 ...                        ...
# 32323  13b25797ad1e6d6c7cd3cbeb35f8ee7a  moveis_colchao_e_estofado
# 32324  dc36a7859b743d8610a2bbbaea26ece9  moveis_colchao_e_estofado
# 32325  107fde0930956120d1e13dd1062fbb46  moveis_colchao_e_estofado
# 32326  726b4e18f00255e2e63491bcba3f60b8  moveis_colchao_e_estofado
# 32327  1dceebcc5f23c02ea23e16d5bedca000          cds_dvds_musicais
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                     40.0                       287.0                 1.0
# ...

# %%
#merging mql and deals
df_mqldeals = df_mql.merge(df_closed_deals,how ='left',on = ['mql_id'],indicator='merge1')
df_mqldeals
# Out:
#                                 mql_id first_contact_date  \
# 0     dac32acd4db4c29c230538b72f8dd87d         2018-02-01
# 1     8c18d1de7f67e60dbd64e3c07d7e9d5d         2017-10-20
# 2     b4bc852d233dfefc5131f593b538befa         2018-03-22
# 3     6be030b81c75970747525b843c1ef4f8         2018-01-22
# 4     5420aad7fec3549a85876ba1c529bd84         2018-02-21
# ...                                ...                ...
# 7995  feaba3ffcd2ff97501696c7f9a42f41c         2018-05-22
# 7996  a79cb53cd009ab92e0143b92baa2407b         2018-03-27
# 7997  68f049a23ab109c6a0f6989bb9a02994         2017-08-27
# 7998  4f8c96e2509b984329044c6682c88ee9         2017-10-06
# 7999  8a6492305a5fbcdcdd1a7f5a90764c07         2018-01-11
#
#                        landing_page_id          origin  \
# 0     88740e65d5d6b056e0cda098e1ea6313          social
# 1     007f9098284a86ee80ddeb25d53e0af8     paid_search
# 2     a7982125ff7aa3b2054c6e44f9d28522  organic_search
# ...

# %%
df_mqldeals.columns
# Out:
# Index(['mql_id', 'first_contact_date', 'landing_page_id', 'origin',
#        'seller_id', 'sdr_id', 'sr_id', 'won_date', 'business_segment',
#        'lead_type', 'lead_behaviour_profile', 'business_type',
#        'declared_monthly_revenue'],
#       dtype='object')

# %%
print(df_orderitems_customers_sellers_payments.shape)
print('\n')
print(df_productscategory.shape)
print('\n')
print(df_mqldeals.shape)
print('\n')
# Out:
# (117601, 25)
#
#
# (32328, 10)
#
#
# (8000, 13)

# %%
##loading staging into Database
import psycopg2
import sqlalchemy
from sqlalchemy import create_engine
dbconn = psycopg2.connect("dbname=Olist_dw user=postgres password=Singh&&71")
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:Singh&&71@localhost:5432/postgres')

# %%
#loading order_staging
#df_orderitems_customers_sellers_payments.to_sql('order_staging',engine,if_exists='replace')
"""Large dataframe exporting the csv"""
#df_orderitems_customers_sellers_payments.to_csv("/private/tmp/df_orderitems_customers_sellers_payments.csv",index=False)
#df_productscategory.to_csv("/private/tmp/df_productscategory.csv",index=False)
#df_mqldeals.to_csv("/private/tmp/df_mqldeals.csv",index=False)
# Out:
# 'Large dataframe exporting the csv'

# %%
#loading order_staging

# %%
#loading order_staging
#df_mqldeals.to_csv("/Users/Rishabh/Desktop/College stuff/Coursework/3rd sem/689/Term_project_DW/Data/df_mq.csv")
